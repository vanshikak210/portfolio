# %% [markdown]
# ---
# layout: post
# title: 3.04 Strings HW
# categories: [Python]
# permalink: /python/strings-intercepters-hw
# author: vanshikak210
# ---

# %%
# CODE_RUNNER: Popcorn Hack 1 - Clean and inspect a raw string using strip, lower, replace, split, find, and count

raw = "   SFI-BACKEND says: the SPEC is DUPLICATE!!!  "

clean = raw.strip()

print(clean)

print(clean.lower())
print(clean.replace("!", ""))
print(clean.split(":"))
print("duplicate" in clean.lower())
print(clean.find("SPEC"))
print(clean.count("S"))

# %%
# CODE_RUNNER: Popcorn Hack 2 - Build status reports using concatenation, str(), f-strings, and join

part = "Flywheel Assembly"
status = "validated"
count = 3

report = part + " status: " + status
report_with_number = part + " matched " + str(count) + " specs"

print(report)
print(report_with_number)

report_f = f"{part} status: {status} ({count} specs matched)"
print(report_f)

spec_numbers = ["1.1", "1.2", "2.1"]
print("-".join(spec_numbers))

# %%
# CODE_RUNNER: Popcorn Hack 3 - Parse the raw transmission and build a markdown row and JSON line

import json

raw_transmission = "  2026-09-15,GHOST,THE-EAGLE-LANDS-AT-DAWN,87  "

segments = raw_transmission.strip().split(",")
print("Segments:", segments)

date = segments[0]
agent = segments[1]
message_code = segments[2]
confidence_str = segments[3]

print("Date:", date, "| Agent:", agent, "| Message code:", message_code, "| Confidence:", confidence_str)

year_check = date[:4] == "2026"
print("Year check:", year_check)

message = message_code.replace("-", " ")

found_dawn = "dawn" in message.lower()
print("Found 'dawn':", found_dawn)

markdown_row = f"| {date} | {agent} | {message} | {confidence_str}% |"
print("Markdown row:", markdown_row)

json_line = json.dumps({
    "date": date,
    "agent": agent,
    "message": message,
    "confidence": int(confidence_str),
    "contains_dawn": found_dawn
})
print("JSON line:", json_line)

# %%
# CODE_RUNNER: Homework - Parse the raw transmission and build a markdown row and JSON line

import json

raw_transmission = "  2026-09-15,GHOST,THE-EAGLE-LANDS-AT-DAWN,87  "

segments = raw_transmission.strip().split(",")
print("Segments:", segments)

date = segments[0]
agent = segments[1]
message_code = segments[2]
confidence_str = segments[3]

print("Date:", date, "| Agent:", agent, "| Message code:", message_code, "| Confidence:", confidence_str)

year_check = date[:4] == "2026"
print("Year check:", year_check)

message = message_code.replace("-", " ")

found_dawn = "dawn" in message.lower()
print("Found 'dawn':", found_dawn)

markdown_row = f"| {date} | {agent} | {message} | {confidence_str}% |"
print("Markdown row:", markdown_row)

json_line = json.dumps({
    "date": date,
    "agent": agent,
    "message": message,
    "confidence": int(confidence_str),
    "contains_dawn": found_dawn
})
print("JSON line:", json_line)
