# %% [markdown]
# ```yaml
# ---
# layout: post
# title: 3.1 Variables and Assignments HW
# categories: [Python]
# lesson_language: Python
# permalink: /python/variables-assignments-hw
# author: vanshikak210
# ---
# ```
